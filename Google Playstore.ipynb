# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/dkada/Desktop/Dataset/archive-3/googleplaystore.csv")

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
data.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
data.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
data.shape
# Out:
# (10841, 13)

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data = data.dropna(subset=['Type','Content Rating','Current Ver','Android Ver'])

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1469
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
data.shape
# Out:
# (10829, 13)

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10829 non-null  object
#  1   Category        10829 non-null  object
#  2   Rating          9360 non-null   float64
#  3   Reviews         10829 non-null  int32
#  4   Size            10829 non-null  object
#  5   Installs        10829 non-null  object
#  6   Type            10829 non-null  object
#  7   Price           10829 non-null  object
#  8   Content Rating  10829 non-null  object
#  9   Genres          10829 non-null  object
#  10  Last Updated    10829 non-null  object
#  11  Current Ver     10829 non-null  object
#  12  Android Ver     10829 non-null  object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 1.1+ MB

# %%
data['Reviews'] = data['Reviews'].astype(int)
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_10632\3426637583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Reviews'] = data['Reviews'].astype(int)

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Installs  Type Price Content Rating  \
# 0      159  19M   10,000+  Free     0       Everyone
# 1      967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
len(data[data['Size'].str.contains('M')]['Reviews'])
# Out:
# 8823

# %%
data['Size'] = data['Size'].str.replace('M','')

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Installs  Type Price Content Rating  \
# 0      159   19   10,000+  Free     0       Everyone
# 1      967   14  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data[data['Size'] == '8.7']
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 624                          Live chat - free video chat               DATING
# 1012                                                my4D               EVENTS
# 1455                            Latest 2018 Home Designs       HOUSE_AND_HOME
# 2117                                      Ice Cream Jump               FAMILY
# 2821                                           HD Camera          PHOTOGRAPHY
# 3355                      XOS - Launcher,Theme,Wallpaper      PERSONALIZATION
# 3753                        Kurio - Read the Latest News   NEWS_AND_MAGAZINES
# 4425         O Launcher 8.0 for Android™ O Oreo Launcher                TOOLS
# 5129                                            AG Track                TOOLS
# 5307                             Ak Parti Yardım Toplama               SOCIAL
# ...

# %%
data['Size'] = data['Size'].str.replace('8.7','9')
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_10632\522132955.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Size'] = data['Size'].str.replace('8.7','9')

# %%
data[data['Size'] == '8.7']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
data['Size'].sort_values()
# Out:
# 8077                    1.0
# 9973                    1.0
# 5771                    1.0
# 6446                    1.0
# 10808                   1.0
#                 ...
# 1382     Varies with device
# 1381     Varies with device
# 9585     Varies with device
# 1388     Varies with device
# 1184     Varies with device
# Name: Size, Length: 10829, dtype: object

# %%
data[data['Size'] == 'Varies with device']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
data['Size'] = data['Size'].str.replace('np.random.randint(np.arange(4,40))','10')
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_10632\2898093855.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Size'] = data['Size'].str.replace('np.random.randint(np.arange(4,40))','10')

# %%
np.random.randint(np.arange(4,40))
# Out:
# array([ 1,  3,  1,  1,  3,  3,  4,  3,  3,  2, 10, 11, 11,  1, 11, 14, 12,
#         8, 20, 12,  4, 16,  0, 23, 12,  5,  5,  5, 25, 15, 32, 23, 13, 23,
#        25, 12])

# %%
data[data['Size'] == 'np.random.randint(np.arange(4,40))'].shape
# Out:
# (1694, 13)

# %%
data['Size'] = data['Size'].replace(to_replace=('np.random.randint(np.arange(4,40))'), value=5)

# %%
data[data['Size'] == 'np.random.randint(np.arange(4,40))'].shape
# Out:
# (0, 13)

# %%
data['Size'] = data['Size'].str.replace('k','')

# %%
data['Size'] = data['Size'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10829 non-null  object
#  1   Category        10829 non-null  object
#  2   Rating          9360 non-null   float64
#  3   Reviews         10829 non-null  int32
#  4   Size            9135 non-null   float64
#  5   Installs        10829 non-null  object
#  6   Type            10829 non-null  object
#  7   Price           10829 non-null  object
#  8   Content Rating  10829 non-null  object
#  9   Genres          10829 non-null  object
#  10  Last Updated    10829 non-null  object
#  11  Current Ver     10829 non-null  object
#  12  Android Ver     10829 non-null  object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 1.1+ MB

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159  19.0   10,000+  Free     0       Everyone
# 1      967  14.0  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data['Installs'] = data['Installs'].str.replace(',','')

# %%
data['Installs'] = data['Installs'].str.replace('+','')
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_10632\1511666186.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Installs'] = data['Installs'].str.replace('+','')

# %%
data.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#    Reviews  Size Installs  Type Price Content Rating        Genres  \
# 0      159  19.0    10000  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver
# 0  January 7, 2018       1.0.0  4.0.3 and up

# %%
data['Installs'] = data['Installs'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10829 non-null  object
#  1   Category        10829 non-null  object
#  2   Rating          9360 non-null   float64
#  3   Reviews         10829 non-null  int32
#  4   Size            9135 non-null   float64
#  5   Installs        10829 non-null  int32
#  6   Type            10829 non-null  object
#  7   Price           10829 non-null  object
#  8   Content Rating  10829 non-null  object
#  9   Genres          10829 non-null  object
#  10  Last Updated    10829 non-null  object
#  11  Current Ver     10829 non-null  object
#  12  Android Ver     10829 non-null  object
# dtypes: float64(2), int32(2), object(9)
# memory usage: 1.1+ MB

# %%
data['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.rename(columns={'Size':'Size_in_MB_or_KB','Price':'Price_in_$'}, inplace=True)

# %%
data.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#    Reviews  Size_in_MB_or_KB  Installs  Type Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free          0       Everyone
#
#          Genres     Last Updated Current Ver   Android Ver
# 0  Art & Design  January 7, 2018       1.0.0  4.0.3 and up

# %%
data['Price_in_$'] = data['Price_in_$'].str.replace('$','')
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_10632\3643852957.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Price_in_$'] = data['Price_in_$'].str.replace('$','')

# %%
data['Price_in_$'] = data['Price_in_$'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   App               10829 non-null  object
#  1   Category          10829 non-null  object
#  2   Rating            9360 non-null   float64
#  3   Reviews           10829 non-null  int32
#  4   Size_in_MB_or_KB  9135 non-null   float64
#  5   Installs          10829 non-null  int32
#  6   Type              10829 non-null  object
#  7   Price_in_$        10829 non-null  float64
#  8   Content Rating    10829 non-null  object
#  9   Genres            10829 non-null  object
#  10  Last Updated      10829 non-null  object
#  11  Current Ver       10829 non-null  object
#  12  Android Ver       10829 non-null  object
# dtypes: float64(3), int32(2), object(8)
# memory usage: 1.3+ MB

# %%
data.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
# 2    87510               9.0   5000000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
data['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
data.to_csv("C:/Users/dkada/Desktop/Dataset/Google/google.csv")

# %%
data.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
# 2    87510               9.0   5000000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
Category_data = data['Category'].value_counts().head(10)

# %%
Cat = data['Category'].value_counts().head(10).reset_index()
Cat
# Out:
#              index  Category
# 0           FAMILY      1968
# 1             GAME      1144
# 2            TOOLS       841
# 3          MEDICAL       463
# 4         BUSINESS       460
# 5     PRODUCTIVITY       424
# 6  PERSONALIZATION       390
# 7    COMMUNICATION       387
# 8           SPORTS       384
# 9        LIFESTYLE       382

# %%
Cat = Cat.reset_index(drop=True)

# %%
Cat.rename(columns={'index':'Name'},inplace=True)

# %%
Cat
# Out:
#               Name  Category
# 0           FAMILY      1968
# 1             GAME      1144
# 2            TOOLS       841
# 3          MEDICAL       463
# 4         BUSINESS       460
# 5     PRODUCTIVITY       424
# 6  PERSONALIZATION       390
# 7    COMMUNICATION       387
# 8           SPORTS       384
# 9        LIFESTYLE       382

# %%
plt.figure(figsize=(10,5))
plt.barh(Cat.Name, Cat.Category, color='orange')
plt.title("Category Wise Data", fontdict={'color':'Blue','fontsize':20})
plt.xlabel("No of Counts",fontdict={'color':'Black','fontsize':15})
plt.ylabel("Category",fontdict={'color':'Black','fontsize':15})
plt.show()

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
Avg_rating = data.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(10)
Avg_rating
# Out:
# Category
# EVENTS                 4.435556
# EDUCATION              4.389032
# ART_AND_DESIGN         4.377049
# BOOKS_AND_REFERENCE    4.346067
# PERSONALIZATION        4.335256
# PARENTING              4.300000
# GAME                   4.286326
# BEAUTY                 4.278571
# HEALTH_AND_FITNESS     4.277104
# SHOPPING               4.259664
# Name: Rating, dtype: float64

# %%
Avg_rating = Avg_rating.reset_index()
Avg_rating
# Out:
#    index             Category    Rating
# 0      0               EVENTS  4.435556
# 1      1            EDUCATION  4.389032
# 2      2       ART_AND_DESIGN  4.377049
# 3      3  BOOKS_AND_REFERENCE  4.346067
# 4      4      PERSONALIZATION  4.335256
# 5      5            PARENTING  4.300000
# 6      6                 GAME  4.286326
# 7      7               BEAUTY  4.278571
# 8      8   HEALTH_AND_FITNESS  4.277104
# 9      9             SHOPPING  4.259664

# %%
del Avg_rating['index']

# %%
plt.figure(figsize=(20,8))
sns.catplot(x='Category', y='Rating',kind='bar', data=Avg_rating)
plt.xticks(rotation='45')
plt.show()

# %%
Avg_rating
# Out:
#               Category    Rating
# 0               EVENTS  4.435556
# 1            EDUCATION  4.389032
# 2       ART_AND_DESIGN  4.377049
# 3  BOOKS_AND_REFERENCE  4.346067
# 4      PERSONALIZATION  4.335256
# 5            PARENTING  4.300000
# 6                 GAME  4.286326
# 7               BEAUTY  4.278571
# 8   HEALTH_AND_FITNESS  4.277104
# 9             SHOPPING  4.259664

# %%
plt.figure(figsize=(10,5))
plt.bar(Avg_rating.Category, Avg_rating.Rating, data=Avg_rating, color='r')
plt.xticks(rotation='45')
plt.title("Avegare of Category", fontdict={'color':'Blue','fontsize':20})
plt.xlabel("Category",fontdict={'color':'Black','fontsize':15})
plt.ylabel("Average",fontdict={'color':'Black','fontsize':15})
plt.show()

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data[['App','Rating']].sort_values(by='Rating', ascending=False).head(10)
# Out:
#                                                     App  Rating
# 1038                          Mindvalley U Tallinn 2018     5.0
# 9517                                            Ek Vote     5.0
# 9427                                            ei Calc     5.0
# 7367                      Startupticker.ch News, Events     5.0
# 9444  Kolkata News:Anandbazar Patrika,ei samay&AllRa...     5.0
# 9455                                       EJ messenger     5.0
# 5506                                      AQ Ria Retail     5.0
# 9496                                         Master E.K     5.0
# 9498                     EK Bailey Preaching Conference     5.0
# 9503                                     Pyaar Ek Dhoka     5.0

# %%
rating_wise_app_count = data['Rating'].value_counts().head(15).reset_index()
rating_wise_app_count
# Out:
#     index  Rating
# 0     4.4    1108
# 1     4.3    1076
# 2     4.5    1037
# 3     4.2     951
# 4     4.6     823
# 5     4.1     707
# 6     4.0     567
# 7     4.7     499
# 8     3.9     386
# 9     3.8     303
# 10    5.0     274
# 11    3.7     239
# 12    4.8     234
# 13    3.6     174
# 14    3.5     163

# %%
rating_wise_app_count.rename(columns={'index':'Rating','Rating':'Count'}, inplace=True)

# %%
rating_wise_app_count
# Out:
#     Rating  Count
# 0      4.4   1108
# 1      4.3   1076
# 2      4.5   1037
# 3      4.2    951
# 4      4.6    823
# 5      4.1    707
# 6      4.0    567
# 7      4.7    499
# 8      3.9    386
# 9      3.8    303
# 10     5.0    274
# 11     3.7    239
# 12     4.8    234
# 13     3.6    174
# 14     3.5    163

# %%
plt.figure(figsize=(10,5))
plt.scatter(rating_wise_app_count.Rating, rating_wise_app_count.Count)
plt.grid()
plt.title("Rating wise App Count", fontdict={'color':'Blue','fontsize':20})
plt.xlabel("Rating",fontdict={'color':'Black','fontsize':15})
plt.ylabel("Count",fontdict={'color':'Black','fontsize':15})
plt.show()

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data[['App','Reviews']].sort_values(by='Reviews', ascending=False).head(10)
# Out:
#                                            App   Reviews
# 2544                                  Facebook  78158306
# 3943                                  Facebook  78128208
# 336                         WhatsApp Messenger  69119316
# 381                         WhatsApp Messenger  69119316
# 3904                        WhatsApp Messenger  69109672
# 2604                                 Instagram  66577446
# 2611                                 Instagram  66577313
# 2545                                 Instagram  66577313
# 3909                                 Instagram  66509917
# 382   Messenger – Text and Video Chat for Free  56646578

# %%
data.loc[2543:2545]
# Out:
#                              App Category  Rating   Reviews  Size_in_MB_or_KB  \
# 2543  1800 Contacts - Lens Store  MEDICAL     4.7     23160              26.0
# 2544                    Facebook   SOCIAL     4.1  78158306               NaN
# 2545                   Instagram   SOCIAL     4.5  66577313               NaN
#
#         Installs  Type  Price_in_$ Content Rating   Genres    Last Updated  \
# 2543     1000000  Free         0.0       Everyone  Medical   July 27, 2018
# 2544  1000000000  Free         0.0           Teen   Social  August 3, 2018
# 2545  1000000000  Free         0.0           Teen   Social   July 31, 2018
#
#              Current Ver         Android Ver
# 2543               7.4.1          5.0 and up
# 2544  Varies with device  Varies with device
# 2545  Varies with device  Varies with device

# %%
data.loc[3942:3944]
# Out:
#                                  App Category  Rating   Reviews  \
# 3942  Cat Sim Online: Play with Cats   FAMILY     4.6    137198
# 3943                        Facebook   SOCIAL     4.1  78128208
# 3944                  Four In A Line     GAME     3.8     22191
#
#       Size_in_MB_or_KB    Installs  Type  Price_in_$ Content Rating  \
# 3942              81.0     5000000  Free         0.0   Everyone 10+
# 3943               NaN  1000000000  Free         0.0           Teen
# 3944               3.0     1000000  Free         0.0       Everyone
#
#           Genres    Last Updated         Current Ver         Android Ver
# 3942  Simulation  April 22, 2018                 3.7          4.0 and up
# 3943      Social  August 3, 2018  Varies with device  Varies with device
# 3944       Board     May 4, 2015                 1.1          2.3 and up

# %%
Un = data['App'].unique()

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (10346, 13)

# %%
max_Reviews= data[['App','Reviews']].sort_values(by='Reviews', ascending=False).head(10)
max_Reviews
# Out:
#                                                     App   Reviews
# 2544                                           Facebook  78158306
# 336                                  WhatsApp Messenger  69119316
# 2545                                          Instagram  66577313
# 335            Messenger – Text and Video Chat for Free  56642847
# 1670                                     Clash of Clans  44891723
# 4005            Clean Master- Space Cleaner & Antivirus  42916526
# 1654                                     Subway Surfers  27722264
# 3665                                            YouTube  25655305
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...  24900999
# 1660                                       Clash Royale  23133508

# %%
data = data.drop_duplicates(subset='App')

# %%
data.shape
# Out:
# (9648, 13)

# %%
plt.figure(figsize=(10,5))
plt.barh(max_Reviews.App, max_Reviews.Reviews, color='y')
plt.grid()
plt.title("Most Reviews App Names", fontdict={'color':'Blue','fontsize':20})
plt.xlabel("Reviews",fontdict={'color':'Black','fontsize':15})
plt.ylabel("App Names",fontdict={'color':'Black','fontsize':15})
plt.show()

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
Category_wise_reviews = data.groupby('Category')['Reviews'].sum().sort_values(ascending=False).head(15).reset_index()
Category_wise_reviews
# Out:
#               Category    Reviews
# 0                 GAME  622298709
# 1        COMMUNICATION  285811368
# 2                TOOLS  229352567
# 3               SOCIAL  227927801
# 4               FAMILY  143825265
# 5          PHOTOGRAPHY  105351270
# 6        VIDEO_PLAYERS   67484568
# 7         PRODUCTIVITY   55590649
# 8      PERSONALIZATION   53542661
# 9             SHOPPING   44551730
# 10              SPORTS   35348813
# 11       ENTERTAINMENT   34762650
# 12    TRAVEL_AND_LOCAL   26819741
# 13  NEWS_AND_MAGAZINES   23130228
# 14  HEALTH_AND_FITNESS   21361355

# %%
plt.figure(figsize=(20,5))
sns.catplot(x='Category', y='Reviews', kind='bar', data=Category_wise_reviews)
plt.title("Most Reviews Category Names", fontdict={'color':'Blue','fontsize':20})
plt.xlabel("Category",fontdict={'color':'Black','fontsize':15})
plt.ylabel("Count",fontdict={'color':'Black','fontsize':15})
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
plt.bar(Category_wise_reviews.Category, Category_wise_reviews.Reviews, data=Category_wise_reviews, color='orange')
plt.xticks(rotation=45)
plt.show()

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
top_10_games_reveiw_app = data[data['Category'] == 'GAME'][['App','Reviews']].sort_values(by='Reviews', ascending=False).head(20)
top_10_games_reveiw_app
# Out:
#                                                    App   Reviews
# 1670                                    Clash of Clans  44891723
# 1654                                    Subway Surfers  27722264
# 1660                                      Clash Royale  23133508
# 1655                                  Candy Crush Saga  22426677
# 1722                                    My Talking Tom  14891223
# 1675                                       8 Ball Pool  14198297
# 1932                                    Shadow Fight 2  10979062
# 1662                                               Pou  10485308
# 1764                                        Pokémon GO  10424925
# 1694          Minion Rush: Despicable Me Official Game  10216538
# 1893                                           Yes day  10055521
# 1739                          Dream League Soccer 2018   9882639
# 1697                                 My Talking Angela   9881829
# ...

# %%
sns.catplot(x='Reviews', y='App', kind='bar', data=top_10_games_reveiw_app)
plt.title("Top 20 most reviews Apps under Game", fontdict={'color':'red','fontsize':20})
plt.xlabel("Counts",fontdict={'color':'Black','fontsize':15})
plt.ylabel("App Names",fontdict={'color':'Black','fontsize':15})
plt.xticks(rotation=90)
plt.show()

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data[['App','Category','Size_in_MB_or_KB']].sort_values(by='Size_in_MB_or_KB', ascending=False).head(10)
# Out:
#                             App             Category  Size_in_MB_or_KB
# 10798      Word Search Tab 1 FR               FAMILY            1020.0
# 8883                      DTPay             SHOPPING             994.0
# 10402             FH Calculator   HEALTH_AND_FITNESS             992.0
# 7868            CT - DTC Lookup                TOOLS             986.0
# 6798   Battery Notifier BT Free                TOOLS             982.0
# 9410            EI HabitTracker               FAMILY             981.0
# 2524    Super Ear Super Hearing              MEDICAL             980.0
# 5783                Dynamics AX             BUSINESS             976.0
# 2523                Fever Meter              MEDICAL             975.0
# 9916                EU IP Codes  BOOKS_AND_REFERENCE             970.0

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
data[['App','Installs']].sort_values(by='Installs', ascending=False).head(10)
# Out:
#                             App    Installs
# 3736                Google News  1000000000
# 3117  Maps - Navigate & Explore  1000000000
# 3127         Google Street View  1000000000
# 3665                    YouTube  1000000000
# 3687    Google Play Movies & TV  1000000000
# 2554                    Google+  1000000000
# 2545                  Instagram  1000000000
# 2544                   Facebook  1000000000
# 3234                     Google  1000000000
# 152           Google Play Books  1000000000

# %%
data['Type'].value_counts()
# Out:
# Free    8895
# Paid     753
# Name: Type, dtype: int64

# %%
sns.countplot(x='Type', hue='Type',dodge=False, data=data)
plt.title("Free & Paid Apps", fontdict={'color':'grey','fontsize':20})
plt.ylabel("Count",fontdict={'color':'Black','fontsize':15})
plt.xlabel("Type",fontdict={'color':'Black','fontsize':15})
plt.show()

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
no_of_in = data.groupby(['Type'])['Installs'].mean().reset_index()
no_of_in
# Out:
#    Type      Installs
# 0  Free  8.438903e+06
# 1  Paid  7.611404e+04

# %%
sns.countplot(x='Type', hue='Type', data=no_of_in)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
data.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
free = data[data['Type'] == 'Free']
free.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating  \
# 0      159              19.0     10000  Free         0.0       Everyone
# 1      967              14.0    500000  Free         0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
free[['App','Installs']].sort_values(by='Installs', ascending=False).head(10)
# Out:
#                                            App    Installs
# 3687                   Google Play Movies & TV  1000000000
# 1654                            Subway Surfers  1000000000
# 340                                      Gmail  1000000000
# 338               Google Chrome: Fast & Secure  1000000000
# 336                         WhatsApp Messenger  1000000000
# 335   Messenger – Text and Video Chat for Free  1000000000
# 2808                             Google Photos  1000000000
# 3665                                   YouTube  1000000000
# 865                          Google Play Games  1000000000
# 3117                 Maps - Navigate & Explore  1000000000

# %%
paid = data[data['Type'] == 'Paid']
paid.head(2)
# Out:
#                                                App  Category  Rating  Reviews  \
# 234  TurboScan: scan documents and receipts in PDF  BUSINESS     4.7    11442
# 235                 Tiny Scanner Pro: PDF Doc Scan  BUSINESS     4.8    10295
#
#      Size_in_MB_or_KB  Installs  Type  Price_in_$ Content Rating    Genres  \
# 234               6.8    100000  Paid        4.99       Everyone  Business
# 235              39.0    100000  Paid        4.99       Everyone  Business
#
#        Last Updated Current Ver Android Ver
# 234  March 25, 2018       1.5.2  4.0 and up
# 235  April 11, 2017       3.4.6  3.0 and up

# %%
paid[['App','Installs','Size_in_MB_or_KB','Reviews','Rating']].sort_values(by='Installs', ascending=False).head(10)
# Out:
#                                                     App  Installs  \
# 4034                                      Hitman Sniper  10000000
# 2241                                          Minecraft  10000000
# 8860                                        Bloons TD 5   1000000
# 2883                                Facetune - For Free   1000000
# 7417                      Grand Theft Auto: San Andreas   1000000
# 6675                               Infinity Dungeon VIP   1000000
# 2242                         Card Wars - Adventure Time   1000000
# 4842           Zombie Avengers:(Dreamsky)Stickman War Z   1000000
# 9170                      Stickman Legends: Shadow Wars   1000000
# 9165  League of Stickman 2018- Ninja Arena PVP(Dream...   1000000
#
#       Size_in_MB_or_KB  Reviews  Rating
# 4034              29.0   408292     4.6
# 2241               NaN  2376564     4.5
# 8860              94.0   190086     4.6
# 2883              48.0    49553     4.4
# ...
