# %% [markdown]
# # Netflix Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/dkada/Desktop/Dataset/archive-2/netflix_titles.csv")

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
print("Total Rows in Data :", data.shape[0])
print("Total Columns in Data :", data.shape[1])
# Out:
# Total Rows in Data : 8807
# Total Columns in Data : 12

# %%
data.describe(include='all')
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8804           4528                7692
# top         s1  Movie  15-Aug  Rajiv Chilaka  David Attenborough
# freq         1   6131       2             19                  19
# mean       NaN    NaN     NaN            NaN                 NaN
# std        NaN    NaN     NaN            NaN                 NaN
# min        NaN    NaN     NaN            NaN                 NaN
# 25%        NaN    NaN     NaN            NaN                 NaN
# 50%        NaN    NaN     NaN            NaN                 NaN
# 75%        NaN    NaN     NaN            NaN                 NaN
# max        NaN    NaN     NaN            NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7976             8797   8807.000000   8803      8804
# ...

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data['director'] = data['director'].replace(to_replace='NaN',value='No Data')

# %%
data['director'].unique()
# Out:
# array(['Kirsten Johnson', nan, 'Julien Leclercq', ..., 'Majid Al Ansari',
#        'Peter Hewitt', 'Mozez Singh'], dtype=object)

# %%
data['director'] = data['director'].fillna('No Data')

# %%
data['cast'] = data['cast'].fillna('No Data')

# %%
data['country'] = data['country'].fillna('No Data')

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
data.shape
# Out:
# (8790, 12)

# %%
8807-8790
# Out:
# 17

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          No Data
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
data['duration_in_min'] = data['duration'].str.split('min')
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_17428\3992459792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['duration_in_min'] = data['duration'].str.split('min')

# %%
data['New_min']= data['duration'].where(data['duration'].str.contains('min'), other=0)
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_17428\4250389732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['New_min']= data['duration'].where(data['duration'].str.contains('min'), other=0)

# %%
del data['duration_in_min']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duration_in_min'
#
# ...

# %%
data['New_min1'] = data['New_min'].str.split('min')
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_17428\176575877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['New_min1'] = data['New_min'].str.split('min')

# %%
del data['New_min1']

# %%
data['New'] = data['New_min'].str.split(' ')
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_17428\526165964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['New'] = data['New_min'].str.split(' ')

# %%
data[['New1','New3']] = data['New'].str.split(',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [156], in <cell line: 1>()
# ----> 1 data[['New1','New3']] = data['New'].str.split(',')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3643, in DataFrame.__setitem__(self, key, value)
#    3641     self._setitem_frame(key, value)
#    3642 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3643     self._setitem_array(key, value)
#    3644 elif isinstance(value, DataFrame):
#    3645     self._set_item_frame_value(key, value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3702, in DataFrame._setitem_array(self, key, value)
#    3699     return self._setitem_array(key, value)
#    3701 else:
# -> 3702     self._iset_not_inplace(key, value)
#
# ...

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          No Data
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description New_min  (New1, New3)
# 0  As her father nears the end of his life, filmm...  90 min           NaN
# 1  After crossing paths at a party, a Cape Town t...       0           NaN

# %%
data.columns
# Out:
# Index([       'show_id',           'type',          'title',       'director',
#                  'cast',        'country',     'date_added',   'release_year',
#                'rating',       'duration',      'listed_in',    'description',
#               'New_min', ('New1', 'New3')],
#       dtype='object')

# %%
data.head(1)
# Out:
#   show_id   type                 title         director     cast  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  No Data
#
#          country          date_added  release_year rating duration  \
# 0  United States  September 25, 2021          2020  PG-13   90 min
#
#        listed_in                                        description New_min  \
# 0  Documentaries  As her father nears the end of his life, filmm...  90 min
#
#    (New1, New3)
# 0           NaN

# %%
type_of_move = data['type'].value_counts().reset_index()
type_of_move
# Out:
#      index  type
# 0    Movie  6126
# 1  TV Show  2664

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='index', y='type', data=type_of_move)
plt.xlabel("Type")
plt.ylabel("Movie")
plt.title("Types of Shows and Count")
plt.show()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          No Data
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description New_min  (New1, New3)
# 0  As her father nears the end of his life, filmm...  90 min           NaN
# 1  After crossing paths at a party, a Cape Town t...       0           NaN

# %%
Country_wise_movie = data[(data['type'] == 'Movie') & (data['country'] != 'No Data')]['country'].value_counts().head(10).reset_index()
Country_wise_movie
# Out:
#             index  country
# 0   United States     2055
# 1           India      893
# 2  United Kingdom      206
# 3          Canada      122
# 4           Spain       97
# 5           Egypt       92
# 6         Nigeria       86
# 7       Indonesia       77
# 8          Turkey       76
# 9           Japan       76

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='index', data=Country_wise_movie)
plt.xticks(rotation=45)
plt.xlabel("Country")
plt.ylabel("Movie")
plt.title("Country Wise Movie")
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='index',y='country', data=Country_wise_movie)
plt.xticks(rotation=45)
plt.xlabel("Country")
plt.ylabel("Movie")
plt.title("Country Wise Movie")
plt.show()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          No Data
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description New_min  (New1, New3)
# 0  As her father nears the end of his life, filmm...  90 min           NaN
# 1  After crossing paths at a party, a Cape Town t...       0           NaN

# %%
data = data.reset_index()
data.head(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [244], in <cell line: 1>()
# ----> 1 data = data.reset_index()
#       2 data.head(2)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5845, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill)
#    5839         if lab is not None:
#    5840             # if we have the codes, extract the values with a mask
# ...

# %%
del data['level_0']

# %%
data.head(2)
# Out:
#    index show_id     type                 title         director  \
# 0      0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      1      s2  TV Show         Blood & Water          No Data
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description New_min  (New1, New3)
# 0  As her father nears the end of his life, filmm...  90 min           NaN
# 1  After crossing paths at a party, a Cape Town t...       0           NaN

# %%
del data['index']

# %%
data.head(1)
# Out:
#   show_id   type                 title         director     cast  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  No Data
#
#          country          date_added  release_year rating duration  \
# 0  United States  September 25, 2021          2020  PG-13   90 min
#
#        listed_in                                        description New_min  \
# 0  Documentaries  As her father nears the end of his life, filmm...  90 min
#
#    (New1, New3)
# 0           NaN

# %%
Country_wise_TV_show = data[(data['type'] == 'TV Show') & (data['country'] != 'No Data')]['country'].value_counts().head(10).reset_index()
Country_wise_TV_show
# Out:
#             index  country
# 0   United States      754
# 1  United Kingdom      212
# 2           Japan      167
# 3     South Korea      158
# 4           India       79
# 5          Taiwan       68
# 6          Canada       59
# 7          France       49
# 8           Spain       48
# 9       Australia       46

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x='index',y='country', data=Country_wise_TV_show)
plt.xticks(rotation=45)
plt.show()

# %%
data.head(1)
# Out:
#   show_id   type                 title         director     cast  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  No Data
#
#          country          date_added  release_year rating duration  \
# 0  United States  September 25, 2021          2020  PG-13   90 min
#
#        listed_in                                        description New_min  \
# 0  Documentaries  As her father nears the end of his life, filmm...  90 min
#
#    (New1, New3)
# 0           NaN

# %%
year = data['release_year'].value_counts().reset_index().head(10)
year
# Out:
#    index  release_year
# 0   2018          1146
# 1   2017          1030
# 2   2019          1030
# 3   2020           953
# 4   2016           901
# 5   2021           592
# 6   2015           555
# 7   2014           352
# 8   2013           286
# 9   2012           236

# %%
plt.barh(year.index, year.release_year)
# Out:
# <BarContainer object of 10 artists>

# %%
sns.barplot(x='index', y='release_year', data=year)
plt.title("Year wise Movie Count")
plt.xlabel("Year")
plt.ylabel("Movies")
plt.show()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          No Data
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description New_min  (New1, New3)
# 0  As her father nears the end of his life, filmm...  90 min           NaN
# 1  After crossing paths at a party, a Cape Town t...       0           NaN

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
rating = data['rating'].value_counts()
rating
# Out:
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: rating, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.pie(rating.values, labels=rating.index,wedgeprops={'edgecolor':'black'}, autopct='%0.1f%%')
plt.show()

# %%
Country_wise_TV_show
# Out:
#             index  country
# 0   United States      754
# 1  United Kingdom      212
# 2           Japan      167
# 3     South Korea      158
# 4           India       79
# 5          Taiwan       68
# 6          Canada       59
# 7          France       49
# 8           Spain       48
# 9       Australia       46

# %%
plt.barh(rating.index, rating.values,color='orange')
plt.show()

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          No Data
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description New_min  (New1, New3)
# 0  As her father nears the end of his life, filmm...  90 min           NaN
# 1  After crossing paths at a party, a Cape Town t...       0           NaN

# %%
data[data['country']=='India']['release_year'].value_counts().sort_values(ascending=False).head(10)
# Out:
# 2017    101
# 2018     94
# 2019     87
# 2020     75
# 2016     73
# 2015     62
# 2013     54
# 2014     51
# 2012     38
# 2010     35
# Name: release_year, dtype: int64

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          No Data
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description New_min  (New1, New3)
# 0  As her father nears the end of his life, filmm...  90 min           NaN
# 1  After crossing paths at a party, a Cape Town t...       0           NaN

# %%
data[(data['country'] == 'India') & (data['release_year'] == 2017) & (data['rating'] == 'TV-MA')]['title']
# Out:
# 3467                                          Inmates
# 3783                              III Smoking Barrels
# 4098                                            Ayana
# 4101                                        Candyflip
# 4190                                         Pandigai
# 4224                                 Puriyatha Puthir
# 4225                                         Taramani
# 4346                                     Power Paandi
# 4506                             Meghnadbodh Rohoshyo
# 4668                                  Love and Shukla
# 4885                                             Ajji
# 4945                                          Ittefaq
# 5088                              The House Next Door
# 5122                                          Muramba
# 5135                              Jab Harry Met Sejal
# 5334      Baahubali 2: The Conclusion (Hindi Version)
# 5371    Aditi Mittal: Things They Wouldn't Let Me Say
# ...

# %%
data.head(1)
# Out:
#   show_id   type                 title         director     cast  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  No Data
#
#          country          date_added  release_year rating duration  \
# 0  United States  September 25, 2021          2020  PG-13   90 min
#
#        listed_in                                        description New_min  \
# 0  Documentaries  As her father nears the end of his life, filmm...  90 min
#
#    (New1, New3)
# 0           NaN

# %%
data['listed_in'].value_counts().head(20)
# Out:
# Dramas, International Movies                         362
# Documentaries                                        359
# Stand-Up Comedy                                      334
# Comedies, Dramas, International Movies               274
# Dramas, Independent Movies, International Movies     252
# Kids' TV                                             219
# Children & Family Movies                             215
# Children & Family Movies, Comedies                   201
# Documentaries, International Movies                  186
# Dramas, International Movies, Romantic Movies        180
# Comedies, International Movies                       176
# Comedies, International Movies, Romantic Movies      152
# Dramas                                               137
# Dramas, International Movies, Thrillers              134
# Action & Adventure, Dramas, International Movies     132
# Action & Adventure                                   128
# ...

# %%
list1 = []
for item in data['listed_in']:
    list1.append(item.split(','))

# %%
list1
# Out:
# [['Documentaries'],
#  ['International TV Shows', ' TV Dramas', ' TV Mysteries'],
#  ['Crime TV Shows', ' International TV Shows', ' TV Action & Adventure'],
#  ['Docuseries', ' Reality TV'],
#  ['International TV Shows', ' Romantic TV Shows', ' TV Comedies'],
#  ['TV Dramas', ' TV Horror', ' TV Mysteries'],
#  ['Children & Family Movies'],
#  ['Dramas', ' Independent Movies', ' International Movies'],
#  ['British TV Shows', ' Reality TV'],
#  ['Comedies', ' Dramas'],
#  ['Crime TV Shows', ' Docuseries', ' International TV Shows'],
#  ['Crime TV Shows', ' International TV Shows', ' TV Action & Adventure'],
#  ['Dramas', ' International Movies'],
#  ['Children & Family Movies', ' Comedies'],
#  ['British TV Shows', ' Crime TV Shows', ' Docuseries'],
#  ['TV Comedies', ' TV Dramas'],
#  ['Documentaries', ' International Movies'],
#  ['Crime TV Shows', ' Spanish-Language TV Shows', ' TV Dramas'],
#  ['Thrillers'],
#  ['International TV Shows',
#   ' Spanish-Language TV Shows',
# ...

# %%
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water          No Data
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          No Data
# 4         s5  TV Show           Kota Factory          No Data
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          No Data
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        No Data
# ...

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
data['Duration_in_min']=data['duration'].str.replace('min', '')

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description Duration_in_min
# 0  As her father nears the end of his life, filmm...             90
# 1  After crossing paths at a party, a Cape Town t...       2 Seasons

# %%
data = data['Duration_in_min'].dropna(axis=0)

# %%
data['Duration_in_min'].isnull()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Duration_in_min'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data['Dur'] = data['duration'].str.replace('min','')

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description        Dur
# 0  As her father nears the end of his life, filmm...        90
# 1  After crossing paths at a party, a Cape Town t...  2 Seasons

# %%
data['Dur'].isnull().sum()
# Out:
# 3

# %%
data = data.dropna(subset=['Dur'])

# %%
data.shape
# Out:
# (8804, 13)

# %%
data['Dur'].isnull().sum()
# Out:
# 0

# %%
dur_uni = data[data['Dur'].str.contains('Seasons')]['Dur'].unique()

# %%
dur_uni
# Out:
# array(['2 Seasons', '9 Seasons', '4 Seasons', '5 Seasons', '3 Seasons',
#        '6 Seasons', '7 Seasons', '10 Seasons', '8 Seasons', '17 Seasons',
#        '13 Seasons', '15 Seasons', '12 Seasons', '11 Seasons'],
#       dtype=object)

# %%
data = data['Dur'].replace(to_replace=dur_uni, value=0)

# %%
data['Dur'] = data['Dur'].str.replace('1 Season','0')

# %%
data = data.dropna(subset=['Dur'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7921 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7921 non-null   object
#  1   type          7921 non-null   object
#  2   title         7921 non-null   object
#  3   director      6124 non-null   object
#  4   cast          7161 non-null   object
#  5   country       7146 non-null   object
#  6   date_added    7921 non-null   object
#  7   release_year  7921 non-null   int64
#  8   rating        7917 non-null   object
#  9   duration      7921 non-null   object
#  10  listed_in     7921 non-null   object
#  11  description   7921 non-null   object
#  12  Dur           7921 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 866.4+ KB

# %%
data['Dur'] = data['Dur'].astype(int)
# Out:
# C:\Users\dkada\AppData\Local\Temp\ipykernel_500\2634451712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Dur'] = data['Dur'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7921 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7921 non-null   object
#  1   type          7921 non-null   object
#  2   title         7921 non-null   object
#  3   director      6124 non-null   object
#  4   cast          7161 non-null   object
#  5   country       7146 non-null   object
#  6   date_added    7921 non-null   object
#  7   release_year  7921 non-null   int64
#  8   rating        7917 non-null   object
#  9   duration      7921 non-null   object
#  10  listed_in     7921 non-null   object
#  11  description   7921 non-null   object
#  12  Dur           7921 non-null   int32
# dtypes: int32(1), int64(1), object(11)
# memory usage: 835.4+ KB

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating  duration  \
# 0  September 25, 2021          2020  PG-13    90 min
# 2  September 24, 2021          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  Dur
# 0  As her father nears the end of his life, filmm...   90
# 2  To protect his family from a powerful drug lor...    0

# %%
data[['title','Dur']].max()
# Out:
# title    최강전사 미니특공대 : 영웅의 탄생
# Dur                      312
# dtype: object

# %%
max_dur = data[['title','Dur']].sort_values(by='Dur',ascending=False).head(10)
max_dur
# Out:
#                             title  Dur
# 4253   Black Mirror: Bandersnatch  312
# 717   Headspace: Unwind Your Mind  273
# 2491       The School of Mischief  253
# 2487               No Longer kids  237
# 2484           Lock Your Girls In  233
# 2488              Raya and Sakina  230
# 166   Once Upon a Time in America  229
# 7932                       Sangam  228
# 1019                       Lagaan  224
# 4573                 Jodhaa Akbar  214

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='title', y='Dur', data=max_dur)
plt.xticks(rotation=45)
plt.legend(['title','Duration'])
plt.show()
